# %%
exec(open("init_notebook.py", "r").read())
import h5py
import os
import scipy.io as sio
# Out:
# current working dirC:\Users\abjawad\Documents\GitHub\local-attention-model

# %%
MAT_PATH1 = 'data\classMapping40.mat'


file = sio.loadmat(MAT_PATH1)

className = file['className']
mapClass = file['mapClass']
mapToNYUSuperClass = file['mapToNYUSuperClass']
mapToNYUSuperClassMat = file['mapToNYUSuperClassMat']
allClassName = file['allClassName']


#  len of className 
print('len of class name ', len(className[0]))
print('len of mapClass ', len(mapClass[0]))
print('len of mapToNYUSuperClass ', len(mapToNYUSuperClass[0]))
print('len of mapToNYUSuperClassMat ', len(mapToNYUSuperClassMat[0]))
print('len of allClassName ', len(allClassName[0]))


print('class name ', className[0])
print('mapClass ', mapClass[0])
print('mapToNYUSuperClass ', mapToNYUSuperClass[0])
print('mapToNYUSuperClassMat ', mapToNYUSuperClassMat[0])
print('allClassName ', allClassName[0])
# Out:
# len of class name  40
# len of mapClass  894
# len of mapToNYUSuperClass  40
# len of mapToNYUSuperClassMat  40
# len of allClassName  894
# class name  [array(['wall'], dtype='<U4') array(['floor'], dtype='<U5')
#  array(['cabinet'], dtype='<U7') array(['bed'], dtype='<U3')
#  array(['chair'], dtype='<U5') array(['sofa'], dtype='<U4')
#  array(['table'], dtype='<U5') array(['door'], dtype='<U4')
#  array(['window'], dtype='<U6') array(['bookshelf'], dtype='<U9')
#  array(['picture'], dtype='<U7') array(['counter'], dtype='<U7')
#  array(['blinds'], dtype='<U6') array(['desk'], dtype='<U4')
#  array(['shelves'], dtype='<U7') array(['curtain'], dtype='<U7')
#  array(['dresser'], dtype='<U7') array(['pillow'], dtype='<U6')
#  array(['mirror'], dtype='<U6') array(['floor mat'], dtype='<U9')
#  array(['clothes'], dtype='<U7') array(['ceiling'], dtype='<U7')
#  array(['books'], dtype='<U5') array(['refridgerator'], dtype='<U13')
# ...

# %%
MAT_PATH2 = 'data\class13Mapping.mat'

file = sio.loadmat(MAT_PATH2)

file.keys()
classMapping13 = file['classMapping13']
print(len(classMapping13[0][0][0][0]))

# className = file['className']
# mapClass = file['mapClass']
# mapToNYUSuperClass = file['mapToNYUSuperClass']
# mapToNYUSuperClassMat = file['mapToNYUSuperClassMat']
# allClassName = file['allClassName']


# #  len of className 
# print('len of class name ', len(className[0]))
# print('len of mapClass ', len(mapClass[0]))
# print('len of mapToNYUSuperClass ', len(mapToNYUSuperClass[0]))
# print('len of mapToNYUSuperClassMat ', len(mapToNYUSuperClassMat[0]))
# print('len of allClassName ', len(allClassName[0]))
# Out:
# 40
